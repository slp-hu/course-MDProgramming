# %%
# %pip install -q otter-grader

# %%
#@title 準備（このセルを実行してください）
import os, urllib.request
os.makedirs('tests', exist_ok=True)
for _n in ['q1.py']:
    urllib.request.urlretrieve('https://raw.githubusercontent.com/slp-hu/course-MDProgramming/main/L01/tests/' + _n, os.path.join('tests', _n))

def assert_equal(name, actual, expected):
    assert actual == expected, f"{name} の値が正しくありません。"

def assert_close(name, actual, expected, tol=1e-9):
    assert abs(actual - expected) < tol, f"{name} の値が正しくありません。"

# %%
# Initialize Otter
import otter
grader = otter.Notebook()

# %% [markdown]
# **問1.** リストを受け取り、平均を返す関数 `mean_of` を定義してください。
#
# _Points:_ 10

# %%
def mean_of(xs):
    ...

# %%
grader.check("q1")
